# %%
# Link to the Kaggle datasheet
# https://www.kaggle.com/leonardopena/top-spotify-songs-from-20102019-by-year

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
# display directly in notebook
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('top10songs.csv')
df = df.drop(['Unnamed: 0'],axis=1)
df
# Out:
#                                                  title            artist  \
# 0                                     Hey, Soul Sister             Train
# 1                                 Love The Way You Lie            Eminem
# 2                                              TiK ToK             Kesha
# 3                                          Bad Romance         Lady Gaga
# 4                                 Just the Way You Are        Bruno Mars
# ..                                                 ...               ...
# 598                Find U Again (feat. Camila Cabello)       Mark Ronson
# 599      Cross Me (feat. Chance the Rapper & PnB Rock)        Ed Sheeran
# 600  No Brainer (feat. Justin Bieber, Chance the Ra...         DJ Khaled
# 601    Nothing Breaks Like a Heart (feat. Miley Cyrus)       Mark Ronson
# 602                                   Kills You Slowly  The Chainsmokers
#
#            top genre  year  bpm  nrgy  dnce  dB  live  val  dur  acous  spch  \
# ...

# %%
# Ideas?

# df[df['dnce']>=90] - shows ~10 rows of the danceability levels above 90
# tf-idf: what words in a song title result in more popularity?
# linear regression
# graphs: scatterplots, boxplots, histograms, pairedplots(?), etc
#

# %% [markdown]
# **Top Genre:** the genre of the track (algorithm, region)
# **Energy:** The energy of a song - the higher the value, the more energtic the song
# **Danceability:** The higher the value, the easier it is to dance to this song.
# **Loudness (dB):** The higher the value, the louder the song
# **Liveness:** The higher the value, the more likely the song is a live recording
# **Valence:** The higher the value, the more positive mood for the song.
# **Duration:** The duration of the song.
# **Acousticness:** The higher the value the more acoustic the song is.
# **Speechiness:** The higher the value the more spoken word the song contains.
# **Popularity:** The higher the value the more popular the song is.

# %%
# No null

null_rows = df.isnull().any(axis=1).sum()
null_rows
# Out:
# 0

# %%
# all together - a complete mess, change diag? change year cols/rows
# takes awhile to load
sns.pairplot(data=df)
plt.show()

# %%
# scatter plot with line - just an example   //vs lmplot?
# fig,axes=plt.subplots(1 , 2, figsize=(25,25)) , ax=axes[0,0]
sns.regplot(data=df, x="val", y="nrgy")
plt.show()
# remove col="year" if for all
sns.lmplot(data=df, x="val", y="nrgy", col="year")
plt.show()

# %%
# Linear Regression - predictors ~ outcomes
# patsy.dmatrices(...)

# %%
# TF-IDF: titles word freq, more important words relate to popularity

# %%
# sns.histplot(data=df, x="val", y="nrgy") see number of songs from each year
# expand x axis
sns.distplot(df['year'],kde = False)
plt.show()

# %%
# idk figure out later


# df_temp = df_all[['State','year','Party']]
# df_temp = df_temp.drop_duplicates(keep='first').reset_index()
# df_temp = df_temp.drop(['index'],axis=1)
# df_temp = df_temp.sort_values('year')

# df.plot(kind='barh',x='year', figsize=(25,20),title='State vs Follower Count')
# plt.show()

# %%
# unique genres
df_temp = df['top genre'].drop_duplicates(keep='first').reset_index()
df_temp = df_temp.drop(['index'],axis=1)
df_temp = df_temp.sort_values('top genre')
df_temp
# reset index, counts, more uniqueness, artists (and their more likely genres)
# Out:
#                     top genre
# 15               acoustic pop
# 24               alaska indie
# 49            alternative r&b
# 10                    art pop
# 7                 atl hip hop
# 30           australian dance
# 28         australian hip hop
# 8              australian pop
# 6               barbadian pop
# 18                baroque pop
# 35                belgian edm
# 12                   big room
# 17                   boy band
# 13               british soul
# 45                    brostep
# 32  canadian contemporary r&b
# 22           canadian hip hop
# 40             canadian latin
# 4                canadian pop
# 23                  candy pop
# 19                celtic rock
# 14                chicago rap
# 11              colombian pop
# 21                 complextro
# 46       contemporary country
# 2                   dance pop
# 38                 danish pop
# 1             detroit hip hop
# 44                  downtempo
# 42                        edm
# ...

# %%
# brainstorm ideas (as of 1/16/2021)

# genre frequency by year (changes?/subgenres of pop changing throughout years)
    
# artists activity/occurence in making into the top list over the years - regression? line plot?
    # bigger names? provide list for students to tweak?
    
# song lifetime as the top song - being replaced by other popular songs of that year
    # performance down? other songs are also hits?
    # ex: katy perry always being on the top of the list -> replacement? performance?

# outliers / unique values in the top genres (count)  + look above 
    # random dot on bottom left graphs?

# etc


    
# how long will the kit be? (completion)
